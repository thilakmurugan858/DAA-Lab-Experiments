# %% [markdown]
# <a href="https://colab.research.google.com/github/thilakmurugan858/DAA-Lab-Experiments/blob/main/DAA4c.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import heapq

def dijkstra_with_hops(graph, start):
    n = len(graph)

    dist = [float('inf')] * n
    hops = [float('inf')] * n
    parent = [-1] * n

    dist[start] = 0
    hops[start] = 0

    pq = [(0, 0, start)]  # (distance, hops, node)

    while pq:
        d, h, u = heapq.heappop(pq)

        if d > dist[u]:
            continue

        for v, w in graph[u]:
            new_dist = d + w
            new_hops = h + 1

            if (new_dist < dist[v]) or (
                new_dist == dist[v] and new_hops < hops[v]
            ):
                dist[v] = new_dist
                hops[v] = new_hops
                parent[v] = u
                heapq.heappush(pq, (new_dist, new_hops, v))

    return dist, hops, parent

def get_path(parent, destination):
    path = []
    while destination != -1:
        path.append(destination)
        destination = parent[destination]
    return path[::-1]

# Graph with 6 vertices
graph = [
    [(1, 2), (2, 4)],
    [(2, 1), (3, 7)],
    [(3, 3), (4, 5)],
    [(5, 1)],
    [(5, 2)],
    []
]

dist, hops, parent = dijkstra_with_hops(graph, 0)

for i in range(len(graph)):
    print(f"Vertex {i}: Distance = {dist[i]}, Hops = {hops[i]}, Path = {get_path(parent, i)}")
# Out:
# Vertex 0: Distance = 0, Hops = 0, Path = [0]
# Vertex 1: Distance = 2, Hops = 1, Path = [0, 1]
# Vertex 2: Distance = 3, Hops = 2, Path = [0, 1, 2]
# Vertex 3: Distance = 6, Hops = 3, Path = [0, 1, 2, 3]
# Vertex 4: Distance = 8, Hops = 3, Path = [0, 1, 2, 4]
# Vertex 5: Distance = 7, Hops = 4, Path = [0, 1, 2, 3, 5]
